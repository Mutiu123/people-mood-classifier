# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import load_model

# %%
# Test
imag = cv2.imread('test2.jpg')
plt.imshow(cv2.cvtColor(imag, cv2.COLOR_BGR2RGB))
plt.show()

# %%
reSize = tf.image.resize(imag, (256, 256))
reSize_rgb = cv2.cvtColor(reSize.numpy().astype(np.uint8), cv2.COLOR_BGR2RGB)
plt.imshow(reSize_rgb)
plt.show()

# %%
new_model = load_model(os.path.join('../model', 'best_model.h5'))
yhat_new = new_model.predict(np.expand_dims(reSize/255, 0))
# Out:
# 1/1 [==============================] - 0s 443ms/step

# %%
yhat_new
# Out:
# array([[0.9839473]], dtype=float32)

# %%
if yhat_new > 0.5:
    print(f'Predicted class is Sad')
else:
    print(f'Predicted class is Happy')
# Out:
# Predicted class is Sad
